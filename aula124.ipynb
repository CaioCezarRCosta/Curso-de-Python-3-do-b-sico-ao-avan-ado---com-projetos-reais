# %% [markdown]
# Métodos úteis dos dicionários em Python

# %% [markdown]
# - len - Quantas chaves
# - keys - Iterável com as chaves
# - values - Iterável com os valores
# - items - Iterável com as chaves e valores
# - setdefault - Adiciona valor se a chave não existe
# - copy - Retorna uma cópia rasa (Shallow copy)
# - get - Obtém a chave
# - pop - Apaga um tem com a chave especificada (del)
# - popitem - Apaga o último item adicionado
# - update - Atualiza um dicionário com outro

# %% [markdown]
# Dicionário exemplo

# %%
p1 = {
    'nome': 'Caio Cezar',
    'sobrenome': 'Ribeiro Costa'
}

# %% [markdown]
# get

# %%
p1 = {
    'nome': 'Caio Cezar',
    #'sobrenome': 'Ribeiro Costa'
}
print(p1['nome'])
print('-'*100)
print(p1.get('nome','Não Existe'))

# %% [markdown]
# pop

# %%
p1 = {
    'nome': 'Caio Cezar',
    'sobrenome': 'Ribeiro Costa'
}
nome = p1.pop('nome')
print(p1)
print('-'*100)
print(nome)
# Out:
# {'sobrenome': 'Ribeiro Costa'}
# ----------------------------------------------------------------------------------------------------
# Caio Cezar

# %% [markdown]
# popitem

# %%
p1 = {
    'nome': 'Caio Cezar',
    'sobrenome': 'Ribeiro Costa'
}
ultima_chave = p1.popitem()
print(ultima_chave)
print('-'*100)
print(p1)
# Out:
# ('sobrenome', 'Ribeiro Costa')
# ----------------------------------------------------------------------------------------------------
# {'nome': 'Caio Cezar'}

# %% [markdown]
# update

# %%
p1 = {
    'nome': 'Caio Cezar',
    'sobrenome': 'Ribeiro Costa'
}

p1.update({
    'nome': 'Novo valor',
    'idade': 30
})

print(p1)
# Out:
# {'nome': 'Novo valor', 'sobrenome': 'Ribeiro Costa', 'idade': 30}

# %% [markdown]
# Outra forma de usar update

# %%
p1.update(nome='novo valor', idade=40)
print(p1)
# Out:
# {'nome': 'novo valor', 'sobrenome': 'Ribeiro Costa', 'idade': 40}

# %% [markdown]
# outra forma de usar update

# %%
tupla = ('nome', 'novo valor'), ('idade',30)
p1.update(tupla)
print('-'*100)
