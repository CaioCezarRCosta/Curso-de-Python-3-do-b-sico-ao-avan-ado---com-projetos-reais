# %% [markdown]
# Métodos úteis dos dicionários em Python

# %% [markdown]
# - len - Quantas chaves
# - keys - Iterável com as chaves
# - values - Iterável com os valores
# - items - Iterável com as chaves e valores
# - setdefault - Adiciona valor se a chave não existe
# - copy - Retorna uma cópia rasa (Shallow copy)
# - get - Obtém a chave
# - pop - Apaga um tem com a chave especificada (del)
# - popitem - Apaga o último item adicionado
# - update - Atualiza um dicionário com outro

# %% [markdown]
# Dicionário Exemplo

# %%
pessoa = {
    'nome': 'Caio Cezar',
    'sobrenome': 'Ribeiro costa 1',
    'sobrenome': 'Ribeiro costa 2 ',
    'sobrenome': 'Ribeiro costa 3 '
}

# %%
pessoa = {
    'nome': 'Caio Cezar',
    'sobrenome': 'Ribeiro costa'
}

# %% [markdown]
# len

# %%
print(len(pessoa))
#Mesmo a chave se repetindo, ele só conta o ultimo registro da chave
# Out:
# 2

# %% [markdown]
# keys

# %%
print(list(pessoa.keys()))
print('-'*100)
for chave in pessoa.keys():
    print(chave)
# Out:
# ['nome', 'sobrenome']
# ----------------------------------------------------------------------------------------------------
# nome
# sobrenome

# %% [markdown]
# values

# %%
print(list(pessoa.values()))
print('-'*100)
for valor in pessoa.values():
    print(valor)
#Mesmo a chave se repetindo, ele só conta o ultimo registro da chave
# Out:
# ['Caio Cezar', 'Ribeiro costa 3 ']
# ----------------------------------------------------------------------------------------------------
# Caio Cezar
# Ribeiro costa 3

# %% [markdown]
# items

# %%
print(list(pessoa.items()))
print('-'*100)
for chave in pessoa.items():
    print(chave)
#Uma lista com tuplas dentro
# Out:
# [('nome', 'Caio Cezar'), ('sobrenome', 'Ribeiro costa 3 ')]
# ----------------------------------------------------------------------------------------------------
# ('nome', 'Caio Cezar')
# ('sobrenome', 'Ribeiro costa 3 ')

# %%
print(pessoa['idade'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(pessoa['idade'])
#
# KeyError: 'idade'

# %% [markdown]
# setdefault

# %%
pessoa.setdefault('idade',0)
print(pessoa['idade'])
# Out:
# 0
